# %% [markdown]
# <a href="https://colab.research.google.com/github/Taishin0719/Deep-Learning1/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
set1= {2, 1, 2, 3, 2, 3, 1, 3, 3, 1}
set1
# Out:
# {1, 2, 3}

# %%
type(set1)
# Out:
# set

# %%
set2 = set() # 空のセット
set2
# Out:
# set()

# %%
set2 = {} # 空の辞書
set2
# Out:
# {}

# %%
set([1,1,2,2,2,3])
# Out:
# {1, 2, 3}

# %%
set((1,1,2,2,2,3))
# Out:
# {1, 2, 3}

# %%
set("aabdceabdae")
# Out:
# {'a', 'b', 'c', 'd', 'e'}

# %%
set({"apple" : 3, "pen" : 5})
# Out:
# {'apple', 'pen'}

# %%
len(set1) # 集合を構築する要素数
# Out:
# 3

# %%
x,y,z = set1 #多重代入
x
# Out:
# 1

# %%
2 in set1 # 指定した要素を集合が含むかどうかの判定
# Out:
# True

# %%
10 in set1 # 指定した要素を集合が含むかどうかの判定
# Out:
# False

# %%
10 not in set1
# Out:
# True

# %%
set1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5731/2166654704.py in <cell line: 0>()
# ----> 1 set1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

# %%
set1 | set2 # 和集合
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1 & set2 # 積集合
# Out:
# {3, 4}

# %%
set1 - set2 # 差集合
# Out:
# {1, 2}

# %%
set1 ^ set2 # 対称差
# Out:
# {1, 2, 5, 6}

# %%
print({1, 2, 3} == {1, 2, 3})
print({1, 2} == {1, 2, 3})
# Out:
# True
# False

# %%
print({1, 2, 3} != {1, 2, 3})
print({1, 2} != {1, 2, 3})
# Out:
# False
# True

# %%
print({1, 2, 3} <= {1, 2, 3})
print({1, 2, 3} < {1, 2, 3})
print({1, 2} < {1, 2, 3})
# Out:
# True
# False
# True

# %%
print({1, 2} <= {2, 3, 4})
# Out:
# False

# %%
set1 = {1, 2, 3}
set1.add(4)
set1
# Out:
# {1, 2, 3, 4}

# %%
set1.remove(1)
set1
# Out:
# {2, 3, 4}

# %%
set1.remove(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5731/760318040.py in <cell line: 0>()
# ----> 1 set1.remove(10)
#
# KeyError: 10

# %%
set1 = {1, 2, 3, 4}
set1.discard(1)
set1
# Out:
# {2, 3, 4}

# %%
set1 = {1, 2, 3, 4}
set1.clear()
set1
# Out:
# set()

# %%
set1 = {1, 2, 3, 4}
print(set1.pop())
print(set1)
# Out:
# 1
# {2, 3, 4}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
set1.union(set2) # 和集合
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.intersection(set2) # 積集合
# Out:
# {3, 4}

# %%
set1.difference(set2) # 差集合
# Out:
# {1, 2}

# %%
set1.symmetric_difference(set2) # 対称差
# Out:
# {1, 2, 5, 6}
