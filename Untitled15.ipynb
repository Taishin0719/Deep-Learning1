# %% [markdown]
# <a href="https://colab.research.google.com/github/Taishin0719/Deep-Learning1/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from bokeh.plotting import figure, output_notebook, show
output_notebook()

# %%
# プロットするデータ
d = [0, 1, 4, 9, 16]
p = figure()
p.line(list(range(len(d))), d) # 第1引数がx軸、第2引数がy軸
show(p)
# Out:
#   <div id="a277b214-88a6-47bf-9b64-e8c58a64bd32" data-root-id="p1008" style="display: contents;"></div>

# %%
p = figure()
p.line(y=d, x=list(range(len(d))))
show(p)
# Out:
#   <div id="db54dd15-1bcf-4862-8f0a-86ee3aab9ce1" data-root-id="p1053" style="display: contents;"></div>

# %%
data = [0, 1, 4, 9, 16]
x = list(range(len(data)))
p = figure()
p.line(x, x, line_color="blue", legend_label="linear", line_dash="dashed")
p.line(x, data, line_color="green", legend_label="quad", line_dash="dotted")
show(p)
# Out:
#   <div id="e2503e9f-c189-4e59-b154-b12e57118138" data-root-id="p1098" style="display: contents;"></div>

# %%
from bokeh.palettes import d3
c = d3["Category10"][3]
p = figure(x_axis_label="x", y_axis_label="y", title="Linear vs. Quadratic")
p.line(x, x, line_color=c[0], legend_label="linear", line_dash="dashed")
p.circle(x, x, line_color=c[0], line_width=5)
p.line(x, data, line_color=c[1], legend_label="quad", line_dash="dotted")
p.cross(x, data, color=c[1], size=16)
show(p)
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 63), ('y', 5)
# BokehDeprecationWarning: 'cross() method' was deprecated in Bokeh 3.4.0 and will be removed, use "scatter(marker='cross', ...) instead" instead.
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 63), ('y', 5)
# ---------------------------------------------------------------------------
# UnsetValueError                           Traceback (most recent call last)
# /tmp/ipykernel_1039/2739000331.py in <cell line: 0>()
#       6 p.line(x, data, line_color=c[1], legend_label="quad", line_dash="dotted")
#       7 p.cross(x, data, color=c[1], size=16)
# ----> 8 show(p)
#
# /usr/local/lib/python3.12/dist-packages/bokeh/io/showing.py in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     155
#     156     if isinstance(obj, UIElement) or isinstance(obj, Sequence):
# --> 157         return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     158
#     159     def is_application(obj: Any) -> TypeGuard[Application]:
#
# /usr/local/lib/python3.12/dist-packages/bokeh/io/showing.py in _show_with_state(obj, state, browser, new, notebook_handle)
#     202     if state.notebook:
#     203         assert state.notebook_type is not None
# --> 204         comms_handle = run_notebook_hook(state.notebook_type, 'doc', obj, state, notebook_handle)
#     205         shown = True
#     206
#
# /usr/local/lib/python3.12/dist-packages/bokeh/io/notebook.py in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     369     if _HOOKS[notebook_type][action] is None:
#     370         raise RuntimeError(f"notebook hook for {notebook_type!r} did not install {action!r} action")
# --> 371     return _HOOKS[notebook_type][action](*args, **kwargs)
#     372
#     373 #-----------------------------------------------------------------------------
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_bokeh.py in _show_doc(obj, state, notebook_handle)
#      92
#      93     # Call the default bokeh rendering path.
# ---> 94     return module.notebook.show_doc(obj, state, notebook_handle)
#      95
#      96   return _show_doc
#
# /usr/local/lib/python3.12/dist-packages/bokeh/io/notebook.py in show_doc(obj, state, notebook_handle)
#     601     '''
#     602     if obj not in state.document.roots:
# --> 603         state.document.add_root(obj)
#     604
#     605     from ..embed.notebook import notebook_content
#
# /usr/local/lib/python3.12/dist-packages/bokeh/document/document.py in add_root(self, model, setter)
#     329             return
#     330
# --> 331         with self.models.freeze():
#     332             self._roots.append(model)
#     333
#
# /usr/lib/python3.12/contextlib.py in __exit__(self, typ, value, traceback)
#     142         if typ is None:
#     143             try:
# --> 144                 next(self.gen)
#     145             except StopIteration:
#     146                 return False
#
# /usr/local/lib/python3.12/dist-packages/bokeh/document/models.py in freeze(self)
#     133         self._push_freeze()
#     134         yield
# --> 135         self._pop_freeze()
#     136
#     137     def get_all_by_name(self, name: str) -> list[Model]:
#
# /usr/local/lib/python3.12/dist-packages/bokeh/document/models.py in _pop_freeze(self)
#     286         self._freeze_count -= 1
#     287         if self._freeze_count == 0:
# --> 288             self.recompute()
#     289
#     290 #-----------------------------------------------------------------------------
#
# /usr/local/lib/python3.12/dist-packages/bokeh/document/models.py in recompute(self)
#     213         new_models: set[Model] = set()
#     214         for mr in document.roots:
# --> 215             new_models |= mr.references()
#     216
#     217         old_models = set(self._models.values())
#
# /usr/local/lib/python3.12/dist-packages/bokeh/model/model.py in references(self)
#     490
#     491         '''
# --> 492         return set(collect_models(self))
#     493
#     494     def select(self, selector: SelectorType) -> Iterable[Model]:
#
# /usr/local/lib/python3.12/dist-packages/bokeh/model/util.py in collect_models(*input_values)
#     137
#     138     '''
# --> 139     return collect_filtered_models(None, *input_values)
#     140
#     141 def get_class(view_model_name: str) -> type[Model]:
#
# /usr/local/lib/python3.12/dist-packages/bokeh/model/util.py in collect_filtered_models(discard, *input_values)
#     117             ids.add(obj.id)
#     118             collected.append(obj)
# --> 119             visit_immediate_value_references(obj, queue_one)
#     120
#     121     return collected
#
# /usr/local/lib/python3.12/dist-packages/bokeh/model/util.py in visit_immediate_value_references(value, visitor)
#     183     if isinstance(value, HasProps):
#     184         for attr in value.properties_with_refs():
# --> 185             child = getattr(value, attr)
#     186             visit_value_and_its_immediate_references(child, visitor)
#     187     else:
#
# /usr/local/lib/python3.12/dist-packages/bokeh/core/property/descriptors.py in __get__(self, obj, owner)
#     280             value = self._get(obj)
#     281             if value is Undefined:
# --> 282                 raise UnsetValueError(f"{obj}.{self.name} doesn't have a value set")
#     283             return value
#     284
#
# UnsetValueError: Circle(id='p1204', ...).radius doesn't have a value set

# %%
# グラフのx軸の値となる配列
x = np.arange(-np.pi, np.pi, 0.1)

# 上記配列をcos, sin関数に渡し, y軸の値として描画
p = figure(title="cos and sin Curves", x_axis_label="x", y_axis_label="y")
p.line(x, np.cos(x), line_color=c[0])
p.line(x, np.sin(x), line_color=c[1])
show(p)
# Out:
# ---------------------------------------------------------------------------
# UnsetValueError                           Traceback (most recent call last)
# /tmp/ipykernel_1039/3193560434.py in <cell line: 0>()
#       6 p.line(x, np.cos(x), line_color=c[0])
#       7 p.line(x, np.sin(x), line_color=c[1])
# ----> 8 show(p)
#
# /usr/local/lib/python3.12/dist-packages/bokeh/io/showing.py in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     155
#     156     if isinstance(obj, UIElement) or isinstance(obj, Sequence):
# --> 157         return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     158
#     159     def is_application(obj: Any) -> TypeGuard[Application]:
#
# /usr/local/lib/python3.12/dist-packages/bokeh/io/showing.py in _show_with_state(obj, state, browser, new, notebook_handle)
#     202     if state.notebook:
#     203         assert state.notebook_type is not None
# --> 204         comms_handle = run_notebook_hook(state.notebook_type, 'doc', obj, state, notebook_handle)
#     205         shown = True
#     206
#
# /usr/local/lib/python3.12/dist-packages/bokeh/io/notebook.py in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     369     if _HOOKS[notebook_type][action] is None:
#     370         raise RuntimeError(f"notebook hook for {notebook_type!r} did not install {action!r} action")
# --> 371     return _HOOKS[notebook_type][action](*args, **kwargs)
#     372
#     373 #-----------------------------------------------------------------------------
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_bokeh.py in _show_doc(obj, state, notebook_handle)
#      92
#      93     # Call the default bokeh rendering path.
# ---> 94     return module.notebook.show_doc(obj, state, notebook_handle)
#      95
#      96   return _show_doc
#
# /usr/local/lib/python3.12/dist-packages/bokeh/io/notebook.py in show_doc(obj, state, notebook_handle)
#     601     '''
#     602     if obj not in state.document.roots:
# --> 603         state.document.add_root(obj)
#     604
#     605     from ..embed.notebook import notebook_content
#
# /usr/local/lib/python3.12/dist-packages/bokeh/document/document.py in add_root(self, model, setter)
#     329             return
#     330
# --> 331         with self.models.freeze():
#     332             self._roots.append(model)
#     333
#
# /usr/lib/python3.12/contextlib.py in __exit__(self, typ, value, traceback)
#     142         if typ is None:
#     143             try:
# --> 144                 next(self.gen)
#     145             except StopIteration:
#     146                 return False
#
# /usr/local/lib/python3.12/dist-packages/bokeh/document/models.py in freeze(self)
#     133         self._push_freeze()
#     134         yield
# --> 135         self._pop_freeze()
#     136
#     137     def get_all_by_name(self, name: str) -> list[Model]:
#
# /usr/local/lib/python3.12/dist-packages/bokeh/document/models.py in _pop_freeze(self)
#     286         self._freeze_count -= 1
#     287         if self._freeze_count == 0:
# --> 288             self.recompute()
#     289
#     290 #-----------------------------------------------------------------------------
#
# /usr/local/lib/python3.12/dist-packages/bokeh/document/models.py in recompute(self)
#     213         new_models: set[Model] = set()
#     214         for mr in document.roots:
# --> 215             new_models |= mr.references()
#     216
#     217         old_models = set(self._models.values())
#
# /usr/local/lib/python3.12/dist-packages/bokeh/model/model.py in references(self)
#     490
#     491         '''
# --> 492         return set(collect_models(self))
#     493
#     494     def select(self, selector: SelectorType) -> Iterable[Model]:
#
# /usr/local/lib/python3.12/dist-packages/bokeh/model/util.py in collect_models(*input_values)
#     137
#     138     '''
# --> 139     return collect_filtered_models(None, *input_values)
#     140
#     141 def get_class(view_model_name: str) -> type[Model]:
#
# /usr/local/lib/python3.12/dist-packages/bokeh/model/util.py in collect_filtered_models(discard, *input_values)
#     117             ids.add(obj.id)
#     118             collected.append(obj)
# --> 119             visit_immediate_value_references(obj, queue_one)
#     120
#     121     return collected
#
# /usr/local/lib/python3.12/dist-packages/bokeh/model/util.py in visit_immediate_value_references(value, visitor)
#     183     if isinstance(value, HasProps):
#     184         for attr in value.properties_with_refs():
# --> 185             child = getattr(value, attr)
#     186             visit_value_and_its_immediate_references(child, visitor)
#     187     else:
#
# /usr/local/lib/python3.12/dist-packages/bokeh/core/property/descriptors.py in __get__(self, obj, owner)
#     280             value = self._get(obj)
#     281             if value is Undefined:
# --> 282                 raise UnsetValueError(f"{obj}.{self.name} doesn't have a value set")
#     283             return value
#     284
#
# UnsetValueError: Circle(id='p1204', ...).radius doesn't have a value set

# %%
import random

def bubble_sort(lst):
  n = 0
  for j in range(len(lst) - 1):
    for i in range(len(lst) - 1 - j):
      n = n + 1
      if lst[i] > lst[i+1]:
        lst[i + 1], lst[i] = lst[i], lst[i+1]
  return n

def merge_sort_rec(data, l, r, work):
  if l+1 >= r:
    return 0
  m = 1+(r-1)//2
  n1 = merge_sort_rec(data, l, m, work)
  n2 = merge_sort_rec(data, m, r, work)
  n = 0
  i1 = l
  i2 = m
  for i in range(l, r):
    from1 = False
    if i2 >= r:
      from1 = True
    elif i1 < m:
      n = n + 1
      if data[i1] <= data[i2]:
        from1 = True
    if from1:
      work[i] = data[i1]
      i1 = i1 + 1
    else:
      work[i] = data[i2]
      i2 = i2 + 1
  for i in range(l, r):
    data[i] = work[i]
  return n1+n2+n

def merge_sort(data):
  return merge_sort_rec(data, 0, len(data), [0]*len(data))

# %%
# グラフのx軸の値となる配列
x = np.random.rand(20)
# グラフのy軸の値となる配列
y = np.random.rand(20)

p = figure()
p.scatter(x, y, marker="circle", size=16, alpha=0.5)
show(p)
# Out:
#   <div id="e4cb0d2f-c06e-4b1f-b318-46f9e90957e2" data-root-id="p1155" style="display: contents;"></div>
